# %%
import pandas as pd
df = pd.read_csv('br_mdr_snis_municipio_agua_esgoto.csv', #sep=';'
                 )
df
# Out:
#          ano  id_municipio sigla_uf  populacao_atendida_agua  \
# 0       2018       2705606       AL                   5276.0
# 1       2018       2707107       AL                  18502.0
# 2       2021       2709152       AL                  39000.0
# 3       2017       2709301       AL                  51589.0
# 4       2021       2902104       BA                  35540.0
# ...      ...           ...      ...                      ...
# 119251  2022       1300805       AM                  30805.0
# 119252  2022       2102077       MA                   4678.0
# 119253  2022       1506104       PA                  10000.0
# 119254  2022       2500577       PB                      0.0
# 119255  2022       4311734       RS                   2800.0
#
#         populacao_atentida_esgoto  populacao_urbana  \
# 0                          3000.0            7665.0
# 1                          8292.0           14245.0
# 2                         28000.0           37674.0
# ...

# %%
print(' \n'.join(df.columns))
# Out:
# populacao_urbana_atendida_esgoto
# populacao_urbana_residente_esgoto_ibge
# volume_esgoto_coletado
# volume_esgoto_tratado
# indice_coleta_esgoto
# indice_tratamento_esgoto

# %%
df = df[['populacao_urbana_atendida_esgoto', 
'populacao_urbana_residente_esgoto_ibge', 
'volume_esgoto_coletado', 
'volume_esgoto_tratado', 
'indice_coleta_esgoto', 
'indice_tratamento_esgoto']]

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Profiling Base Dos Dados")
profile.to_file("BaseDosDados.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# c:\Users\lucas\anaconda3\Lib\site-packages\ydata_profiling\utils\dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(df.columns[df.columns.duplicated()])
# Out:
# Index([], dtype='object')
